# %% [markdown]
# #### Install streamlit

# %%
# pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-0.70.0-py2.py3-none-any.whl (7.4 MB)
# Requirement already satisfied: python-dateutil in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (2.8.1)
# Collecting tzlocal
#   Downloading tzlocal-2.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (2.22.0)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (1.0.1)
# Collecting altair>=3.2.0
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
# Collecting base58
#   Downloading base58-2.0.1-py3-none-any.whl (4.3 kB)
# Collecting gitpython
#   Downloading GitPython-3.1.11-py3-none-any.whl (159 kB)
# Collecting validators
#   Downloading validators-0.18.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: cachetools>=4.0 in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (4.1.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (7.0.0)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (20.1)
# Collecting pyarrow
#   Downloading pyarrow-2.0.0-cp37-cp37m-win_amd64.whl (10.7 MB)
# Requirement already satisfied: click>=7.0 in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (7.0)
# Collecting enum-compat
#   Downloading enum_compat-0.0.3-py3-none-any.whl (1.3 kB)
# Collecting botocore>=1.13.44
#   Downloading botocore-1.19.10-py2.py3-none-any.whl (6.7 MB)
# Requirement already satisfied: tornado>=5.0 in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (6.0.3)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (3.12.2)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: watchdog in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.5.0-py2.py3-none-any.whl (4.5 MB)
# Requirement already satisfied: numpy in c:\users\phill\anaconda3\lib\site-packages (from streamlit) (1.18.1)
# Collecting boto3
#   Downloading boto3-1.16.10.tar.gz (97 kB)
# Requirement already satisfied: six>=1.5 in c:\users\phill\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.14.0)
# Requirement already satisfied: pytz in c:\users\phill\anaconda3\lib\site-packages (from tzlocal->streamlit) (2019.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\phill\anaconda3\lib\site-packages (from requests->streamlit) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\phill\anaconda3\lib\site-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\phill\anaconda3\lib\site-packages (from requests->streamlit) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phill\anaconda3\lib\site-packages (from requests->streamlit) (2019.11.28)
# Requirement already satisfied: jinja2 in c:\users\phill\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.1)
# Requirement already satisfied: toolz in c:\users\phill\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.10.0)
# Requirement already satisfied: jsonschema in c:\users\phill\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: entrypoints in c:\users\phill\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.5-py3-none-any.whl (63 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\phill\anaconda3\lib\site-packages (from validators->streamlit) (4.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\phill\anaconda3\lib\site-packages (from packaging->streamlit) (2.4.6)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: setuptools in c:\users\phill\anaconda3\lib\site-packages (from protobuf>=3.6.0->streamlit) (45.2.0.post20200210)
# Requirement already satisfied: pathtools>=0.1.1 in c:\users\phill\anaconda3\lib\site-packages (from watchdog->streamlit) (0.1.2)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\phill\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.5.1)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\phill\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (4.3.3)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in c:\users\phill\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.4)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\phill\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\phill\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\phill\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (1.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\phill\anaconda3\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.15.7)
# Collecting smmap<4,>=3.0.1
#   Downloading smmap-3.0.4-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\phill\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.4)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\phill\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (7.12.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\phill\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: ipython-genutils in c:\users\phill\anaconda3\lib\site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jupyter-client in c:\users\phill\anaconda3\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\phill\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair>=3.2.0->streamlit) (2.2.0)
# Requirement already satisfied: jupyter-core in c:\users\phill\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.6.1)
# Requirement already satisfied: backcall in c:\users\phill\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.0)
# Requirement already satisfied: pygments in c:\users\phill\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.5.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\phill\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.3)
# Requirement already satisfied: pickleshare in c:\users\phill\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\phill\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.0.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\phill\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.14.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\phill\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.3)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\phill\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: pyzmq>=13 in c:\users\phill\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (18.1.1)
# Requirement already satisfied: wcwidth in c:\users\phill\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.8)
# Requirement already satisfied: parso>=0.5.0 in c:\users\phill\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.2)
# Requirement already satisfied: Send2Trash in c:\users\phill\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\phill\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: prometheus-client in c:\users\phill\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: nbconvert in c:\users\phill\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.6.1)
# Requirement already satisfied: bleach in c:\users\phill\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.1.0)
# Requirement already satisfied: testpath in c:\users\phill\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: defusedxml in c:\users\phill\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\phill\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\phill\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.2)
# Requirement already satisfied: webencodings in c:\users\phill\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Building wheels for collected packages: blinker, boto3
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13455 sha256=4965979b80215e524df08c8eee5d5e231ea3ffa08463d3d97d466e603069021c
#   Stored in directory: c:\users\phill\appdata\local\pip\cache\wheels\22\f5\18\df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
#   Building wheel for boto3 (setup.py): started
#   Building wheel for boto3 (setup.py): finished with status 'done'
#   Created wheel for boto3: filename=boto3-1.16.10-py2.py3-none-any.whl size=128454 sha256=01f98d4e4a8798bd720c635f28f018e3ea84fdded98668f4dea726ec568e0380
#   Stored in directory: c:\users\phill\appdata\local\pip\cache\wheels\84\fd\44\975710e60b7720217addd9560642e50612ea19ef49fdc74073
# Successfully built blinker boto3
# Installing collected packages: tzlocal, blinker, altair, base58, smmap, gitdb, gitpython, validators, astor, pyarrow, enum-compat, jmespath, botocore, toml, pydeck, s3transfer, boto3, streamlit
# Successfully installed altair-4.1.0 astor-0.8.1 base58-2.0.1 blinker-1.4 boto3-1.16.10 botocore-1.19.10 enum-compat-0.0.3 gitdb-4.0.5 gitpython-3.1.11 jmespath-0.10.0 pyarrow-2.0.0 pydeck-0.5.0 s3transfer-0.3.3 smmap-3.0.4 streamlit-0.70.0 toml-0.10.2 tzlocal-2.1 validators-0.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd 
import numpy as np

# %%
# Title of app
st.title('Wainwrights')

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Wainwrights'
html = pd.read_html(url, index_col=0)
df = html[1]

display(df)
print(df.columns.values)
# Out:
#                           Name      Section  Birkett  Height (m)  Prom. (m)  \
# Height Rank
# 1                 Scafell Pike  34B: LD C&W  Birkett         978        912
# 2                      Scafell  34B: LD C&W  Birkett         964        132
# 3                    Helvellyn    34C: LD E  Birkett         950        712
# 4                      Skiddaw    34A: LD N  Birkett         931        709
# 5                    Great End  34B: LD C&W  Birkett         910         56
# ...                        ...          ...      ...         ...        ...
# 210          Rannerdale Knotts  34B: LD C&W  Birkett         355         66
# 211             Loughrigg Fell  34B: LD C&W  Birkett         335        172
# 212                 Black Fell    34D: LD S  Birkett         323        126
# 213                 Holme Fell    34D: LD S  Birkett         317        165
# 214                Castle Crag  34B: LD C&W      NaN         290        951
#
#              Height (ft)  Prom. (ft) Topo Map OS Grid Reference  \
# Height Rank
# 1                   3209        2992    89 90          NY215072
# 2                   3162         434    89 90          NY206064
# 3                   3117        2336       90          NY342151
# 4                   3054        2326    89 90          NY260290
# 5                   2984         184    89 90          NY226083
# ...                  ...         ...      ...               ...
# 210                 1165         217       89          NY167182
# 211                 1099         564       90          NY346051
# 212                 1060         413       90          NY340015
# 213                 1040         541       90          NY315006
# 214                  951        3120    89 90          NY249159
#
#                      Classification(§ DoBIH codes)
# Height Rank
# 1            Ma,F,Sim,Hew,N,W,B,Sy,Fel,CoH,CoU,CoA
# 2                        Hu,F,Sim,Hew,N,W,B,Sy,Fel
# 3                    Ma,F,Sim,Hew,N,W,B,Sy,Fel,CoH
# 4                        Ma,F,Sim,Hew,N,W,B,Sy,Fel
# 5                             Sim,Hew,N,W,B,Sy,Fel
# ...                                            ...
# 210                                   3,W,B,Sy,Fel
# 211                                Ma,3,W,B,Sy,Fel
# 212                                Hu,3,W,B,Sy,Fel
# 213                                Ma,3,W,B,Sy,Fel
# 214                                     2,W,Sy,Fel
#
# [214 rows x 10 columns]
# ['Name' 'Section' 'Birkett' 'Height (m)' 'Prom. (m)' 'Height (ft)'
#  'Prom. (ft)' 'Topo Map' 'OS Grid Reference'
#  'Classification(§\xa0DoBIH codes)']

# %%
df.drop(columns = ['Section', 'Birkett', 'Prom. (m)', 'Prom. (ft)', 'Classification(§\xa0DoBIH codes)'])
# Out:
#                           Name  Height (m)  Height (ft) Topo Map  \
# Height Rank
# 1                 Scafell Pike         978         3209    89 90
# 2                      Scafell         964         3162    89 90
# 3                    Helvellyn         950         3117       90
# 4                      Skiddaw         931         3054    89 90
# 5                    Great End         910         2984    89 90
# ...                        ...         ...          ...      ...
# 210          Rannerdale Knotts         355         1165       89
# 211             Loughrigg Fell         335         1099       90
# 212                 Black Fell         323         1060       90
# 213                 Holme Fell         317         1040       90
# 214                Castle Crag         290          951    89 90
#
#             OS Grid Reference
# Height Rank
# 1                    NY215072
# 2                    NY206064
# 3                    NY342151
# 4                    NY260290
# 5                    NY226083
# ...                       ...
# 210                  NY167182
# 211                  NY346051
# 212                  NY340015
# 213                  NY315006
# 214                  NY249159
#
# [214 rows x 5 columns]
